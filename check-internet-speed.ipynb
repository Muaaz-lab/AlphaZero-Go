# %%
# !pip install speedtest-cli

# %%
import subprocess
print(subprocess.getoutput("speedtest"))
# Out:
# Retrieving speedtest.net configuration...
# Testing from Google Virtual Private Cloud (34.12.137.173)...
# Retrieving speedtest.net server list...
# Selecting best server based on ping...
# Hosted by Eranium B.V. (Amsterdam) [7534.30 km]: 6.155 ms
# Testing download speed................................................................................
# Download: 1313.78 Mbit/s
# Testing upload speed......................................................................................................
# Upload: 1149.09 Mbit/s
